# %% [markdown]
# ### STAGE C TAG ALONG CODES
#
# SUBMITTED BY : CHIMEREMMA SANDRA AMADI
#
# ID: 1572c1a4b801f000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.utils
from sklearn.metrics import recall_score, accuracy_score, precision_score, f1_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
df= pd.read_csv('Data_for_UCI_named.csv')
df
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tau1    10000 non-null  float64
#  1   tau2    10000 non-null  float64
#  2   tau3    10000 non-null  float64
#  3   tau4    10000 non-null  float64
#  4   p1      10000 non-null  float64
#  5   p2      10000 non-null  float64
#  6   p3      10000 non-null  float64
#  7   p4      10000 non-null  float64
#  8   g1      10000 non-null  float64
#  9   g2      10000 non-null  float64
#  10  g3      10000 non-null  float64
#  11  g4      10000 non-null  float64
#  12  stab    10000 non-null  float64
#  13  stabf   10000 non-null  object
# dtypes: float64(13), object(1)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  unstable

# %%
X = df.drop(columns = 'stabf')
y = df['stabf']
scaler = StandardScaler()
X_norm = pd.DataFrame(scaler.fit_transform(X), columns = X.columns)
X_norm.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0 -0.835374 -0.791317  1.141704  1.652103  0.017397  1.079405 -0.017078
# 1  1.478297 -0.126705 -0.803111 -1.415043  1.752124 -1.593619 -1.438158
# 2  1.357093  1.312140 -0.803499 -1.471504 -0.458492  0.098253 -0.062840
# 3 -1.653138  0.882289 -0.278354 -1.060901  0.284250  0.513904 -1.591046
# 4 -0.771543  0.860108 -0.111670  1.680114 -0.298075  0.287450 -1.376343
#
#          p4        g1        g2        g3        g4      stab
# 0 -1.092545  0.457467  1.220013  1.321628  1.579026  1.073120
# 1 -0.011575 -0.406791  1.230354  0.135424  0.936256 -0.587487
# 2  0.760963 -1.319852  0.881299  1.146596 -1.513802 -0.332095
# 3  0.583414 -0.287304  1.647250  1.474543 -0.591750  0.355922
# 4  1.606636  0.992226 -0.253610  0.481133  1.079063  0.924487

# %%
y.value_counts()
# Out:
# unstable    6380
# stable      3620
# Name: stabf, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_norm,y, test_size = 0.2, random_state = 1)

# %% [markdown]
# ###  QUESTION 14

# %%
random_f_clf = RandomForestClassifier(random_state=1)
random_f_clf.fit(X_train, y_train)
random_f_pred = random_f_clf.predict(X_test)

# %% [markdown]
# ### accuracy :

# %%
random_f_pred = random_f_clf.predict(X_test)

accuracy = accuracy_score(y_true=y_test, y_pred=random_f_pred)
print(f'Accuracy: {accuracy:.4f}')
# Out:
# Accuracy: 0.9995

# %% [markdown]
# ### QUESTION 15- XGboost classifier

# %%
 # !pip install xgboost

# %%
from xgboost import XGBClassifier
xgb_clf = XGBClassifier(random_state=1)
xgb_clf.fit(X_train, y_train)
xgb_pred = xgb_clf.predict(X_test)

# %%
xgb_pred = xgb_clf.predict(X_test)

accuracy = accuracy_score(y_true=y_test, y_pred=xgb_pred)
print(f'Accuracy: {accuracy:.4f}')

# %% [markdown]
# ### QUESTION 16- LGBM

# %%
from lightgbm import LGBMClassifier
lgbm_clf = LGBMClassifier(random_state=1)
lgbm_clf.fit(X_train, y_train)
lgbm_pred = lgbm_clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 from lightgbm import LGBMClassifier
#       3 lgbm_clf = LGBMClassifier(random_state=1)
#       4 lgbm_clf.fit(X_train, y_train)
#
# ModuleNotFoundError: No module named 'lightgbm'

# %%
lgbm_pred = lgbm_clf.predict(X_test)
accuracy = accuracy_score(y_true=y_test, y_pred=lgbm_pred)
print(f'Accuracy: {accuracy:.4f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 lgbm_pred = lgbm_clf.predict(X_test)
#       3 accuracy = accuracy_score(y_true=y_test, y_pred=lgbm_pred)
#       4 print(f'accuracy: {accuracy:.4f}')
#
# NameError: name 'lgbm_clf' is not defined

# %% [markdown]
# ### QUESTION 17

# %%
extra_tree_clf = ExtraTreesClassifier( )
extra_tree_clf.get_params().keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 extra_tree_clf = ExtraTreesClassifier( )
#       2 extra_tree_clf.get_params().keys()
#
# NameError: name 'ExtraTreesClassifier' is not defined
